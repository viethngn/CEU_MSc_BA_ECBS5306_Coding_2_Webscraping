# %%
import json
import os
import pandas as pd
import numpy as np

# change this to TRUE if you want to collect data from API
collect_data = False

prog_path = os.getcwd()

# %%
from src.recovery.ps_recovery import remove_invalid_char_for_url
from src.utils.ps_utils import get_ps_replays, save_to_files, get_replay_details, get_player_details


if collect_data:
    replays = get_ps_replays()
    json_formatted_data = json.dumps(replays, indent=4)
    print(json_formatted_data)
    
    # save replays to text
    os.makedirs(f"{prog_path}/replays", exist_ok=True)
    save_to_files(
        f"{prog_path}/replays/replay_save.json",
        replays)
    
    # get replay details:
    r_details = get_replay_details(replays)
    
    # save replay details to file
    save_to_files(
        f"{prog_path}/replays/replay_details.json",
        r_details)
    
    # get player_details for this run
    player_ids = set()
    for replay in replays:
        player_ids.add(remove_invalid_char_for_url(replay['players'][0]))
        player_ids.add(remove_invalid_char_for_url(replay['players'][1]))
    player_details = get_player_details(player_ids)
    
    # save player details to file
    save_to_files(
        f"{prog_path}/replays/player_details.json",
        player_details)
# Out:
# /Users/viethnguyen/Documents/CEU_BA_MSc/Coding_2_Web_Scraping_ECBS5306/CEU_MSc_BA_ECBS5306_Coding_2_Webscraping/venv/lib/python3.9/site-packages/urllib3/__init__.py:34: NotOpenSSLWarning: urllib3 v2 only supports OpenSSL 1.1.1+, currently the 'ssl' module is compiled with 'LibreSSL 2.8.3'. See: https://github.com/urllib3/urllib3/issues/3020
#   warnings.warn(

# %%
from src.utils.ps_game_state_utils import ini_data_file, process_replay_file
from src.utils.ps_utils import load_static_data


if collect_data:
    file_path = f"{prog_path}/replays/replay_details.json"
    output_path = f"{prog_path}/game_state_data/game_state.csv"
    
    ps_static = load_static_data()
    
    # create the output data file
    ini_data_file(output_path)
    
    # track duplicated games
    game_ids = set()
    
    process_replay_file(file_path, output_path, ps_static, game_ids)
    
    print(f"Finished generating games tate data file {output_path}")
    print(f"Number of games: {len(game_ids)}")

# %%
if collect_data:
    game_state_filepath = f"{prog_path}/game_state_data/game_state.csv"
    df = pd.read_csv(game_state_filepath)
else:
    df = pd.read_csv('https://raw.githubusercontent.com/viethngn/CEU_MSc_BA_ECBS5306_Coding_2_Webscraping/main/game_state_data/game_state.csv')
df.info(verbose=True)
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 2850 entries, 0 to 2849
# Data columns (total 228 columns):
#  #    Column                   Dtype
# ---   ------                   -----
#  0    game_id                  object
#  1    p1_win                   int64
#  2    T_ELECTRIC               int64
#  3    T_GRASSY                 int64
#  4    T_MISTY                  int64
#  5    T_PSYCHIC                int64
#  6    W_SUN                    int64
#  7    W_RAIN                   int64
#  8    W_SAND                   int64
#  9    W_SNOW                   int64
#  10   W_EX_SUN                 int64
#  11   W_EX_RAIN                int64
#  12   W_EX_WIND                int64
#  13   R_TRICK_ROOM             int64
#  14   R_WONDER_ROOM            int64
#  15   R_MAGIC_ROOM             int64
#  16   p1_reflect               int64
#  17   p1_light_screen          int64
#  18   p1_tailwind              int64
#  19   p1_webbed                int64
#  20   p1_has_bug               int64
#  21   p1_has_dark              int64
#  22   p1_has_dragon            int64
#  23   p1_has_electric          int64
#  24   p1_has_fairy             int64
#  25   p1_has_fighting          int64
#  26   p1_has_fire              int64
#  27   p1_has_flying            int64
#  28   p1_has_ghost             int64
#  29   p1_has_grass             int64
#  30   p1_has_ground            int64
#  31   p1_has_ice               int64
#  32   p1_has_normal            int64
#  33   p1_has_poison            int64
#  34   p1_has_psychic           int64
#  35   p1_has_rock              int64
#  36   p1_has_steel             int64
#  37   p1_has_water             int64
#  38   p2_reflect               int64
#  39   p2_light_screen          int64
#  40   p2_tailwind              int64
#  41   p2_webbed                int64
#  42   p2_has_bug               int64
#  43   p2_has_dark              int64
#  44   p2_has_dragon            int64
#  45   p2_has_electric          int64
#  46   p2_has_fairy             int64
#  47   p2_has_fighting          int64
#  48   p2_has_fire              int64
#  49   p2_has_flying            int64
#  50   p2_has_ghost             int64
#  51   p2_has_grass             int64
#  52   p2_has_ground            int64
#  53   p2_has_ice               int64
#  54   p2_has_normal            int64
#  55   p2_has_poison            int64
#  56   p2_has_psychic           int64
#  57   p2_has_rock              int64
#  58   p2_has_steel             int64
#  59   p2_has_water             int64
#  60   p1_pkm1_code             object
#  61   p1_pkm1_hp               int64
#  62   p1_pkm1_BURN             int64
#  63   p1_pkm1_FREEZE           int64
#  64   p1_pkm1_PARALYSIS        int64
#  65   p1_pkm1_POISON           int64
#  66   p1_pkm1_BADLY_POISON     int64
#  67   p1_pkm1_SLEEP            int64
#  68   p1_pkm1_volatile_status  int64
#  69   p1_pkm1_atk_boost        int64
#  70   p1_pkm1_def_boost        int64
#  71   p1_pkm1_spa_boost        int64
#  72   p1_pkm1_spd_boost        int64
#  73   p1_pkm1_spe_boost        int64
#  74   p1_pkm2_code             object
#  75   p1_pkm2_hp               int64
#  76   p1_pkm2_BURN             int64
#  77   p1_pkm2_FREEZE           int64
#  78   p1_pkm2_PARALYSIS        int64
#  79   p1_pkm2_POISON           int64
#  80   p1_pkm2_BADLY_POISON     int64
#  81   p1_pkm2_SLEEP            int64
#  82   p1_pkm2_volatile_status  int64
#  83   p1_pkm2_atk_boost        int64
#  84   p1_pkm2_def_boost        int64
#  85   p1_pkm2_spa_boost        int64
#  86   p1_pkm2_spd_boost        int64
#  87   p1_pkm2_spe_boost        int64
#  88   p1_pkm3_code             object
#  89   p1_pkm3_hp               int64
#  90   p1_pkm3_BURN             int64
#  91   p1_pkm3_FREEZE           int64
#  92   p1_pkm3_PARALYSIS        int64
#  93   p1_pkm3_POISON           int64
#  94   p1_pkm3_BADLY_POISON     int64
#  95   p1_pkm3_SLEEP            int64
#  96   p1_pkm3_volatile_status  int64
#  97   p1_pkm3_atk_boost        int64
#  98   p1_pkm3_def_boost        int64
#  99   p1_pkm3_spa_boost        int64
#  100  p1_pkm3_spd_boost        int64
#  101  p1_pkm3_spe_boost        int64
#  102  p1_pkm4_code             object
#  103  p1_pkm4_hp               int64
#  104  p1_pkm4_BURN             int64
#  105  p1_pkm4_FREEZE           int64
#  106  p1_pkm4_PARALYSIS        int64
#  107  p1_pkm4_POISON           int64
#  108  p1_pkm4_BADLY_POISON     int64
#  109  p1_pkm4_SLEEP            int64
#  110  p1_pkm4_volatile_status  int64
#  111  p1_pkm4_atk_boost        int64
#  112  p1_pkm4_def_boost        int64
#  113  p1_pkm4_spa_boost        int64
#  114  p1_pkm4_spd_boost        int64
#  115  p1_pkm4_spe_boost        int64
#  116  p1_pkm5_code             object
#  117  p1_pkm5_hp               int64
#  118  p1_pkm5_BURN             int64
#  119  p1_pkm5_FREEZE           int64
#  120  p1_pkm5_PARALYSIS        int64
#  121  p1_pkm5_POISON           int64
#  122  p1_pkm5_BADLY_POISON     int64
#  123  p1_pkm5_SLEEP            int64
#  124  p1_pkm5_volatile_status  int64
#  125  p1_pkm5_atk_boost        int64
#  126  p1_pkm5_def_boost        int64
#  127  p1_pkm5_spa_boost        int64
#  128  p1_pkm5_spd_boost        int64
#  129  p1_pkm5_spe_boost        int64
#  130  p1_pkm6_code             object
#  131  p1_pkm6_hp               int64
#  132  p1_pkm6_BURN             int64
#  133  p1_pkm6_FREEZE           int64
#  134  p1_pkm6_PARALYSIS        int64
#  135  p1_pkm6_POISON           int64
#  136  p1_pkm6_BADLY_POISON     int64
#  137  p1_pkm6_SLEEP            int64
#  138  p1_pkm6_volatile_status  int64
#  139  p1_pkm6_atk_boost        int64
#  140  p1_pkm6_def_boost        int64
#  141  p1_pkm6_spa_boost        int64
#  142  p1_pkm6_spd_boost        int64
#  143  p1_pkm6_spe_boost        int64
#  144  p2_pkm1_code             object
#  145  p2_pkm1_hp               int64
#  146  p2_pkm1_BURN             int64
#  147  p2_pkm1_FREEZE           int64
#  148  p2_pkm1_PARALYSIS        int64
#  149  p2_pkm1_POISON           int64
#  150  p2_pkm1_BADLY_POISON     int64
#  151  p2_pkm1_SLEEP            int64
#  152  p2_pkm1_volatile_status  int64
#  153  p2_pkm1_atk_boost        int64
#  154  p2_pkm1_def_boost        int64
#  155  p2_pkm1_spa_boost        int64
#  156  p2_pkm1_spd_boost        int64
#  157  p2_pkm1_spe_boost        int64
#  158  p2_pkm2_code             object
#  159  p2_pkm2_hp               int64
#  160  p2_pkm2_BURN             int64
#  161  p2_pkm2_FREEZE           int64
#  162  p2_pkm2_PARALYSIS        int64
#  163  p2_pkm2_POISON           int64
#  164  p2_pkm2_BADLY_POISON     int64
#  165  p2_pkm2_SLEEP            int64
#  166  p2_pkm2_volatile_status  int64
#  167  p2_pkm2_atk_boost        int64
#  168  p2_pkm2_def_boost        int64
#  169  p2_pkm2_spa_boost        int64
#  170  p2_pkm2_spd_boost        int64
#  171  p2_pkm2_spe_boost        int64
#  172  p2_pkm3_code             object
#  173  p2_pkm3_hp               int64
#  174  p2_pkm3_BURN             int64
#  175  p2_pkm3_FREEZE           int64
#  176  p2_pkm3_PARALYSIS        int64
#  177  p2_pkm3_POISON           int64
#  178  p2_pkm3_BADLY_POISON     int64
#  179  p2_pkm3_SLEEP            int64
#  180  p2_pkm3_volatile_status  int64
#  181  p2_pkm3_atk_boost        int64
#  182  p2_pkm3_def_boost        int64
#  183  p2_pkm3_spa_boost        int64
#  184  p2_pkm3_spd_boost        int64
#  185  p2_pkm3_spe_boost        int64
#  186  p2_pkm4_code             object
#  187  p2_pkm4_hp               int64
#  188  p2_pkm4_BURN             int64
#  189  p2_pkm4_FREEZE           int64
#  190  p2_pkm4_PARALYSIS        int64
#  191  p2_pkm4_POISON           int64
#  192  p2_pkm4_BADLY_POISON     int64
#  193  p2_pkm4_SLEEP            int64
#  194  p2_pkm4_volatile_status  int64
#  195  p2_pkm4_atk_boost        int64
#  196  p2_pkm4_def_boost        int64
#  197  p2_pkm4_spa_boost        int64
#  198  p2_pkm4_spd_boost        int64
#  199  p2_pkm4_spe_boost        int64
#  200  p2_pkm5_code             object
#  201  p2_pkm5_hp               int64
#  202  p2_pkm5_BURN             int64
#  203  p2_pkm5_FREEZE           int64
#  204  p2_pkm5_PARALYSIS        int64
#  205  p2_pkm5_POISON           int64
#  206  p2_pkm5_BADLY_POISON     int64
#  207  p2_pkm5_SLEEP            int64
#  208  p2_pkm5_volatile_status  int64
#  209  p2_pkm5_atk_boost        int64
#  210  p2_pkm5_def_boost        int64
#  211  p2_pkm5_spa_boost        int64
#  212  p2_pkm5_spd_boost        int64
#  213  p2_pkm5_spe_boost        int64
#  214  p2_pkm6_code             object
#  215  p2_pkm6_hp               int64
#  216  p2_pkm6_BURN             int64
#  217  p2_pkm6_FREEZE           int64
#  218  p2_pkm6_PARALYSIS        int64
#  219  p2_pkm6_POISON           int64
#  220  p2_pkm6_BADLY_POISON     int64
#  221  p2_pkm6_SLEEP            int64
#  222  p2_pkm6_volatile_status  int64
#  223  p2_pkm6_atk_boost        int64
#  224  p2_pkm6_def_boost        int64
#  225  p2_pkm6_spa_boost        int64
#  226  p2_pkm6_spd_boost        int64
#  227  p2_pkm6_spe_boost        int64
# dtypes: int64(215), object(13)
# memory usage: 5.0+ MB
